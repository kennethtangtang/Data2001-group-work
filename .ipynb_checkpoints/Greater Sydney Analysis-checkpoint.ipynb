# %%
#python connect sql
from sqlalchemy import create_engine, text
import psycopg2
import psycopg2.extras
import pandas as pd
import json
import os

credentials = "Credentials.json"

def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host = db_conn_dict['host']
        db_user = db_conn_dict['user']
        db_pw = db_conn_dict['password']
        default_db = db_conn_dict['database']
    try:
        db = create_engine('postgresql+psycopg2://' + db_user + ':' + db_pw + '@' + host + '/' + default_db, echo=False)
        conn = db.connect()
        conn.autocommit = True
        print('Connected successfully.')
    except Exception as e:
        print("Unable to connect to the database.")
        print(e)
        db, conn = None, None
    return db, conn

def query(conn, sqlcmd, args=None, df=True):
    result = pd.DataFrame() if df else None
    try:
        if df:
            result = pd.read_sql_query(sqlcmd, conn, params=args)
        else:
            result = conn.execute(sqlcmd, args).fetchall()
            result = result[0] if len(result) == 1 else result
    except Exception as e:
        print("Error encountered: ", e, sep='\n')
    return result

db, conn = pgconnect(credentials)
# Out:
# Connected successfully.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon
from geoalchemy2 import Geometry, WKTElement
import matplotlib.pyplot as plt
import numpy as np

srid = 4326
SA2 = gpd.read_file("SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.shp")
SA2 = SA2[SA2['GCC_NAME21'] == 'Greater Sydney']

def create_wkt_element(geom, srid):
    if geom.geom_type == 'Polygon':
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)

SA2['geometry_wkt'] = SA2['geometry'].apply(lambda x: create_wkt_element(x, srid=srid))
SA2 = SA2.drop(columns=['GCC_CODE21', 'GCC_NAME21', 'STE_CODE21', 'STE_NAME21', 'AUS_CODE21', 'AUS_NAME21', 'geometry'])

# %%
conn.execute("""CREATE EXTENSION IF NOT EXISTS postgis;
""")

# %%
conn.execute("""
DROP TABLE IF EXISTS "SA2";
CREATE TABLE "SA2" (
    "SA2_CODE21" INTEGER PRIMARY KEY,
    "SA2_NAME21" VARCHAR(50),
    "CHG_FLAG21" INTEGER,
    "CHG_LBL21" VARCHAR(20),
    "SA3_CODE21" INTEGER,
    "SA3_NAME21" VARCHAR(50),
    "SA4_CODE21" INTEGER,
    "SA4_NAME21" VARCHAR(50),
    "AREASQKM21" FLOAT,
    "LOCI_URI21" VARCHAR(255),
    geom GEOMETRY(MULTIPOLYGON,4326)
);
""")

# %%
SA2.to_sql("SA2", conn, if_exists='replace', index=False, dtype={
    'geometry_wkt': Geometry('MULTIPOLYGON', srid=srid)
})
query(conn, 'SELECT * FROM "SA2"')
# Out:
#     SA2_CODE21                   SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  \
# 0    102011028     Avoca Beach - Copacabana          0  No change      10201
# 1    102011029  Box Head - MacMasters Beach          0  No change      10201
# 2    102011030              Calga - Kulnura          0  No change      10201
# 3    102011031          Erina - Green Point          0  No change      10201
# 4    102011032        Gosford - Springfield          0  No change      10201
# ..         ...                          ...        ...        ...        ...
# 368  128021537          Royal National Park          0  No change      12802
# 369  128021538        Sutherland - Kirrawee          0  No change      12802
# 370  128021607                     Engadine          0  No change      12802
# 371  128021608         Loftus - Yarrawarrah          0  No change      12802
# 372  128021609             Woronora Heights          0  No change      12802
#
#                          SA3_NAME21 SA4_CODE21           SA4_NAME21  \
# 0                           Gosford        102        Central Coast
# 1                           Gosford        102        Central Coast
# 2                           Gosford        102        Central Coast
# 3                           Gosford        102        Central Coast
# 4                           Gosford        102        Central Coast
# ..                              ...        ...                  ...
# 368  Sutherland - Menai - Heathcote        128  Sydney - Sutherland
# 369  Sutherland - Menai - Heathcote        128  Sydney - Sutherland
# 370  Sutherland - Menai - Heathcote        128  Sydney - Sutherland
# 371  Sutherland - Menai - Heathcote        128  Sydney - Sutherland
# 372  Sutherland - Menai - Heathcote        128  Sydney - Sutherland
#
#      AREASQKM21                                         LOCI_URI21  \
# 0        6.4376  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1       32.0802  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2      767.9512  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 3       33.7934  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 4       16.9123  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# ..          ...                                                ...
# 368    139.3336  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 369      7.7550  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 370      8.9538  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 371      3.8436  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 372      3.1374  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                           geometry_wkt
# 0    0106000020E6100000010000000103000000010000005E...
# 1    0106000020E61000000100000001030000000100000010...
# 2    0106000020E61000000200000001030000000100000085...
# 3    0106000020E61000000100000001030000000100000041...
# 4    0106000020E6100000010000000103000000010000007E...
# ..                                                 ...
# 368  0106000020E61000000100000001030000000100000046...
# 369  0106000020E61000000100000001030000000100000089...
# 370  0106000020E6100000010000000103000000010000008E...
# 371  0106000020E610000001000000010300000001000000A1...
# 372  0106000020E610000001000000010300000001000000F0...
#
# [373 rows x 11 columns]

# %%
businesses = pd.read_csv('Businesses.csv')

# %%
conn.execute("""
DROP TABLE IF EXISTS businesses;
CREATE TABLE businesses (
    "industry_code" VARCHAR(5) PRIMARY KEY,
    "industry_name" VARCHAR(50),
    "sa2_code" INTEGER,
    "sa2_name" VARCHAR(50),
    "0_to_50k_businesses" INTEGER,
    "50k_to_200k_businesses" INTEGER,
    "200k_to_2m_businesses" INTEGER,
    "2m_to_5m_businesses" INTEGER,
    "5m_to_10m_businesses" INTEGER,
    "10m_or_more_businesses" INTEGER,
    total_businesses INTEGER
);
""")

# %%
businesses.to_sql("businesses", conn, if_exists='replace', index=False)
query(conn, 'SELECT * FROM "businesses"')
# Out:
#       industry_code                      industry_name   sa2_code  \
# 0                 A  Agriculture, Forestry and Fishing  101021007
# 1                 A  Agriculture, Forestry and Fishing  101021008
# 2                 A  Agriculture, Forestry and Fishing  101021009
# 3                 A  Agriculture, Forestry and Fishing  101021010
# 4                 A  Agriculture, Forestry and Fishing  101021012
# ...             ...                                ...        ...
# 12212             S                     Other Services  128021538
# 12213             S                     Other Services  128021607
# 12214             S                     Other Services  128021608
# 12215             S                     Other Services  128021609
# 12216             S                     Other Services  199999499
#
#                               sa2_name  0_to_50k_businesses  \
# 0                            Braidwood                  136
# 1                              Karabar                    6
# 2                           Queanbeyan                    6
# 3                    Queanbeyan - East                    0
# 4      Queanbeyan West - Jerrabomberra                    7
# ...                                ...                  ...
# 12212            Sutherland - Kirrawee                   21
# 12213                         Engadine                   13
# 12214             Loftus - Yarrawarrah                    0
# 12215                 Woronora Heights                    0
# 12216                Currently Unknown                   32
#
#        50k_to_200k_businesses  200k_to_2m_businesses  2m_to_5m_businesses  \
# 0                          92                     63                    4
# 1                           3                      0                    0
# 2                           4                      3                    0
# 3                           3                      0                    0
# 4                           4                      5                    0
# ...                       ...                    ...                  ...
# 12212                      66                     58                    3
# 12213                      41                     31                    3
# 12214                      10                     10                    0
# 12215                       3                      5                    0
# 12216                      74                     58                   11
#
#        5m_to_10m_businesses  10m_or_more_businesses  total_businesses
# 0                         0                       0               296
# 1                         0                       0                 9
# 2                         0                       3                15
# 3                         0                       0                 3
# 4                         0                       0                16
# ...                     ...                     ...               ...
# 12212                     3                       0               152
# 12213                     0                       0                87
# 12214                     0                       0                22
# 12215                     0                       0                 9
# 12216                     0                      14               190
#
# [12217 rows x 11 columns]

# %%
income = pd.read_csv('Income.csv')

cols_to_convert = ['earners', 'median_age', 'median_income', 'mean_income']
income[cols_to_convert] = income[cols_to_convert].replace('np', np.nan)
for col in cols_to_convert:
    income[col] = pd.to_numeric(income[col], errors='coerce')
    median_val = income[col].median()
    income[col] = income[col].fillna(median_val).astype(int) 
income.dtypes
# Out:
# sa2_code21        int64
# sa2_name         object
# earners           int64
# median_age        int64
# median_income     int64
# mean_income       int64
# dtype: object

# %%
conn.execute("""
DROP TABLE IF EXISTS income;
CREATE TABLE income (
    "sa2_code21" INTEGER PRIMARY KEY,
    "sa2_name" VARCHAR(50),
    "earners" INTEGER,
    "median_age" INTEGER,
    "median_income" INTEGER,
    "mean_income" INTEGER
);
""")

# %%
income.to_sql("income", conn, if_exists='replace', index=False)
query(conn, 'SELECT * FROM "income"')
# Out:
#      sa2_code21                         sa2_name  earners  median_age  \
# 0     101021007                        Braidwood     2467          51
# 1     101021008                          Karabar     5103          42
# 2     101021009                       Queanbeyan     7028          39
# 3     101021010                Queanbeyan - East     3398          39
# 4     101021012  Queanbeyan West - Jerrabomberra     8422          44
# ..          ...                              ...      ...         ...
# 637   128021537              Royal National Park       14          37
# 638   128021538            Sutherland - Kirrawee    13895          41
# 639   128021607                         Engadine    10239          43
# 640   128021608             Loftus - Yarrawarrah     4424          45
# 641   128021609                 Woronora Heights     2491          47
#
#      median_income  mean_income
# 0            46640        68904
# 1            65564        69672
# 2            63528        69174
# 3            66148        74162
# 4            78630        91981
# ..             ...          ...
# 637          36980        47584
# 638          64940        74867
# 639          63695        72995
# 640          63087        76440
# 641          65460        82717
#
# [642 rows x 6 columns]

# %%
stops = pd.read_csv('Stops.txt', quotechar='"')
stops['geometry'] = gpd.points_from_xy(stops['stop_lon'], stops['stop_lat'])
stops
# Out:
#         stop_id  stop_code                             stop_name   stop_lat  \
# 0        200039   200039.0     Central Station, Eddy Av, Stand A -33.882206
# 1        200054   200054.0     Central Station, Eddy Av, Stand D -33.882042
# 2        200060        NaN                       Central Station -33.884084
# 3        201510        NaN                       Redfern Station -33.891690
# 4        201646   201646.0  Redfern Station, Gibbons St, Stand B -33.893329
# ...         ...        ...                                   ...        ...
# 114713   212753   212753.0     Sydney Olympic Park Wharf, Side B -33.822016
# 114714  2137185  2137185.0                Cabarita Wharf, Side A -33.840669
# 114715  2137186  2137186.0                Cabarita Wharf, Side B -33.840769
# 114716    21501    21501.0                      Parramatta Wharf -33.813904
# 114717  2150112        NaN                      Parramatta Wharf -33.813952
#
#           stop_lon  location_type parent_station  wheelchair_boarding  \
# 0       151.206665            NaN         200060                    0
# 1       151.206991            NaN         200060                    0
# 2       151.206292            1.0            NaN                    0
# 3       151.198866            1.0            NaN                    0
# 4       151.198882            NaN         201510                    0
# ...            ...            ...            ...                  ...
# 114713  151.078797            NaN          21271                    1
# 114714  151.116926            NaN          21371                    1
# 114715  151.116899            NaN          21371                    1
# 114716  151.010577            NaN        2150112                    1
# 114717  151.010482            1.0            NaN                    1
#
#        platform_code                     geometry
# 0                NaN  POINT (151.20666 -33.88221)
# 1                NaN  POINT (151.20699 -33.88204)
# 2                NaN  POINT (151.20629 -33.88408)
# 3                NaN  POINT (151.19887 -33.89169)
# 4                NaN  POINT (151.19888 -33.89333)
# ...              ...                          ...
# 114713             B  POINT (151.07880 -33.82202)
# 114714            1A  POINT (151.11693 -33.84067)
# 114715            1B  POINT (151.11690 -33.84077)
# 114716           NaN  POINT (151.01058 -33.81390)
# 114717           NaN  POINT (151.01048 -33.81395)
#
# [114718 rows x 10 columns]

# %%
conn.execute("""
DROP TABLE IF EXISTS stops;
CREATE TABLE stops (
    stop_id VARCHAR(255) PRIMARY KEY,
    stop_code VARCHAR(255),
    stop_name VARCHAR(255),
    stop_lat VARCHAR(255),
    stop_lon VARCHAR(255),
    location_type VARCHAR(255),
    parent_station VARCHAR(255),
    wheelchair_boarding VARCHAR(255),
    platform_code VARCHAR(255),
    geometry_wkt public.GEOMETRY(POINT,4326),
);
""")

# %%
def create_wkt_element(geom, srid=4326):
    return WKTElement(geom.wkt, srid)
stops['geometry_wkt'] = stops['geometry'].apply(lambda x: create_wkt_element(x, srid=srid))
stops = stops.drop(columns=['geometry'])
stops.to_sql('stops', conn, if_exists='replace', index=False, dtype={'geometry_wkt': Geometry('POINT', srid=4326)})
query(conn, 'SELECT * FROM "stops"')
# Out:
#         stop_id  stop_code                             stop_name   stop_lat  \
# 0        200039   200039.0     Central Station, Eddy Av, Stand A -33.882206
# 1        200054   200054.0     Central Station, Eddy Av, Stand D -33.882042
# 2        200060        NaN                       Central Station -33.884084
# 3        201510        NaN                       Redfern Station -33.891690
# 4        201646   201646.0  Redfern Station, Gibbons St, Stand B -33.893329
# ...         ...        ...                                   ...        ...
# 114713   212753   212753.0     Sydney Olympic Park Wharf, Side B -33.822016
# 114714  2137185  2137185.0                Cabarita Wharf, Side A -33.840669
# 114715  2137186  2137186.0                Cabarita Wharf, Side B -33.840769
# 114716    21501    21501.0                      Parramatta Wharf -33.813904
# 114717  2150112        NaN                      Parramatta Wharf -33.813952
#
#           stop_lon  location_type parent_station  wheelchair_boarding  \
# 0       151.206665            NaN         200060                    0
# 1       151.206991            NaN         200060                    0
# 2       151.206292            1.0           None                    0
# 3       151.198866            1.0           None                    0
# 4       151.198882            NaN         201510                    0
# ...            ...            ...            ...                  ...
# 114713  151.078797            NaN          21271                    1
# 114714  151.116926            NaN          21371                    1
# 114715  151.116899            NaN          21371                    1
# 114716  151.010577            NaN        2150112                    1
# 114717  151.010482            1.0           None                    1
#
#        platform_code                                       geometry_wkt
# 0               None  0101000020E6100000FFA631FF9CE66240A1FF6524ECF0...
# 1               None  0101000020E61000002F928BAC9FE66240E33DC7C1E6F0...
# 2               None  0101000020E6100000817FA2F299E662408FF33DAC29F1...
# 3               None  0101000020E61000009E57611C5DE6624060304CE622F2...
# 4               None  0101000020E6100000DBF9333D5DE662403DFA6B9D58F2...
# ...              ...                                                ...
# 114713             B  0101000020E6100000AF9B3D8185E262408F52D7D537E9...
# 114714            1A  0101000020E6100000EB409ADCBDE3624089CE4C0B9BEB...
# 114715            1B  0101000020E6100000C4F9BEA2BDE362403EB375529EEB...
# 114716          None  0101000020E6100000E443E4A456E0624025C1A4032EE8...
# 114717          None  0101000020E6100000F0D5DCDD55E06240526782972FE8...
#
# [114718 rows x 10 columns]

# %%
population = pd.read_csv('Population.csv')

# %%
conn.execute("""
DROP TABLE IF EXISTS population;
CREATE TABLE population (
    "sa2_code" INTEGER PRIMARY KEY,
    "sa2_name" VARCHAR(255),
    "0-4_people" INTEGER,
    "5-9_people" INTEGER,
    "10-14_people" INTEGER,
    "15-19_people" INTEGER,
    "20-24_people" INTEGER,
    "25-29_people" INTEGER,
    "30-34_people" INTEGER,
    "35-39_people" INTEGER,
    "40-44_people" INTEGER,
    "45-49_people" INTEGER,
    "50-54_people" INTEGER,
    "55-59_people" INTEGER,
    "60-64_people" INTEGER,
    "65-69_people" INTEGER,
    "70-74_people" INTEGER,
    "75-79_people" INTEGER,
    "80-84_people" INTEGER,
    "85-and-over_people" INTEGER,
    "total_people" INTEGER
);
""")

# %%
population.to_sql("population", conn, if_exists='replace', index=False)
query(conn, 'SELECT * FROM "population"')
# Out:
#       sa2_code                     sa2_name  0-4_people  5-9_people  \
# 0    102011028     Avoca Beach - Copacabana         424         522
# 1    102011029  Box Head - MacMasters Beach         511         666
# 2    102011030              Calga - Kulnura         200         225
# 3    102011031          Erina - Green Point         683         804
# 4    102011032        Gosford - Springfield        1164        1044
# ..         ...                          ...         ...         ...
# 368  128021537          Royal National Park           2           4
# 369  128021538        Sutherland - Kirrawee        1519        1292
# 370  128021607                     Engadine        1157        1283
# 371  128021608         Loftus - Yarrawarrah         503         487
# 372  128021609             Woronora Heights         166         217
#
#      10-14_people  15-19_people  20-24_people  25-29_people  30-34_people  \
# 0             623           552           386           222           306
# 1             702           592           461           347           420
# 2             258           278           274           227           214
# 3             880           838           661           502           587
# 4            1084          1072          1499          1864          1750
# ..            ...           ...           ...           ...           ...
# 368            10             4             9             7             1
# 369          1150          1117          1335          1852          2120
# 370          1469          1209           891           675           928
# 371           575           508           380           293           426
# 372           272           310           240           153           123
#
#      35-39_people  ...  45-49_people  50-54_people  55-59_people  \
# 0             416  ...           572           602           570
# 1             535  ...           749           749           794
# 2             286  ...           325           436           422
# 3             757  ...           859           882           901
# 4            1520  ...          1330          1241          1377
# ..            ...  ...           ...           ...           ...
# 368             2  ...             4             0             0
# 369          1945  ...          1569          1391          1285
# 370          1229  ...          1315          1086           909
# 371           493  ...           564           477           450
# 372           161  ...           303           316           295
#
#      60-64_people  65-69_people  70-74_people  75-79_people  80-84_people  \
# 0             520           464           369           226           142
# 1             895           863           925           603           331
# 2             397           327           264           190           100
# 3             930           917          1065           976           773
# 4            1285          1166           949           664           476
# ..            ...           ...           ...           ...           ...
# 368             0             1             0             0             0
# 369          1157           909           909           781           582
# 370           764           707           886           748           389
# 371           387           418           335           263           192
# 372           310           217           143            80            30
#
#      85-and-over_people  total_people
# 0                    70          7530
# 1                   264         11052
# 2                    75          4748
# 3                  1028         14803
# 4                   537         21346
# ..                  ...           ...
# 368                   0            45
# 369                 807         23369
# 370                 327         17379
# 371                 109          7354
# 372                  16          3551
#
# [373 rows x 21 columns]

# %%
pollingplaces2019 = pd.read_csv('PollingPlaces2019.csv')
pollingplaces2019['the_geom'] = gpd.points_from_xy(pollingplaces2019.longitude, pollingplaces2019.latitude)
pollingplaces2019['geometry_wkt'] = pollingplaces2019['the_geom'].apply(lambda x: create_wkt_element(geom=x, srid=srid)) 
pollingplaces2019 = pollingplaces2019.drop(columns=['the_geom'])

# %%
conn.execute("""
DROP TABLE IF EXISTS pollingplaces2019;
CREATE TABLE pollingplaces2019 (
    "FID" VARCHAR(255),
    "state" VARCHAR(255),
    "division_id" INTEGER,
    "division_name" VARCHAR(255),
    "polling_place_id" INTEGER PRIMARY KEY,
    "polling_place_type_id" INTEGER,
    "polling_place_name" VARCHAR(255),
    "premises_name" VARCHAR(255),
    "premises_address_1" VARCHAR(255),
    "premises_address_2" VARCHAR(255),
    "premises_address_3" VARCHAR(255),
    "premises_suburb" VARCHAR(255),
    "premises_state_abbreviation" VARCHAR(255),
    "premises_post_code" INTEGER,
    "latitude" FLOAT,
    "longitude" FLOAT,
    geometry_wkt GEOMETRY(MULTIPOLYGON,4326)
);
""")

# %%
pollingplaces2019.to_sql('pollingplaces2019', conn, if_exists='replace', index=False, dtype={'geometry_wkt': Geometry('POINT', srid=4326)})
query(conn, 'SELECT * FROM "pollingplaces2019"')
# Out:
#                                                     FID state  division_id  \
# 0     aec_federal_election_polling_places_2019.fid-4...   NSW          104
# 1     aec_federal_election_polling_places_2019.fid-4...   NSW          105
# 2     aec_federal_election_polling_places_2019.fid-4...   NSW          107
# 3     aec_federal_election_polling_places_2019.fid-4...   NSW          109
# 4     aec_federal_election_polling_places_2019.fid-4...   NSW          113
# ...                                                 ...   ...          ...
# 2925  aec_federal_election_polling_places_2019.fid-4...   NSW          150
# 2926  aec_federal_election_polling_places_2019.fid-4...   NSW          150
# 2927  aec_federal_election_polling_places_2019.fid-4...   NSW          150
# 2928  aec_federal_election_polling_places_2019.fid-4...   NSW          150
# 2929  aec_federal_election_polling_places_2019.fid-4...   NSW          150
#
#      division_name  polling_place_id  polling_place_type_id  \
# 0           Barton             33595                      2
# 1        Bennelong             33596                      2
# 2         Blaxland             33600                      2
# 3           Calare             33603                      2
# 4           Cowper             33716                      2
# ...            ...               ...                    ...
# 2925       Whitlam              2809                      1
# 2926       Whitlam             58798                      5
# 2927       Whitlam             31242                      1
# 2928       Whitlam               564                      1
# 2929       Whitlam             58667                      5
#
#            polling_place_name          premises_name  premises_address_1  \
# 0     Special Hospital Team 1         Multiple sites                None
# 1     Special Hospital Team 1         Multiple sites                None
# 2     Special Hospital Team 1         Multiple sites                None
# 3     Special Hospital Team 1         Multiple sites                None
# 4     Special Hospital Team 2         Multiple sites                None
# ...                       ...                    ...                 ...
# 2925            Warilla South    Warilla High School       10 Keross Ave
# 2926     Warilla WHITLAM PPVC  2/144 Shellharbour Rd                None
# 2927                    Welby   Welby Community Hall  14 Currockbilly St
# 2928                  Windang  Windang Public School   60-64 Oakland Ave
# 2929  Wollongong WHITLAM PPVC          3/51 Crown St                None
#
#      premises_address_2 premises_address_3  premises_suburb  \
# 0                  None               None             None
# 1                  None               None             None
# 2                  None               None             None
# 3                  None               None           ORANGE
# 4                  None               None             None
# ...                 ...                ...              ...
# 2925               None               None  BARRACK HEIGHTS
# 2926               None               None          WARILLA
# 2927               None               None            WELBY
# 2928               None               None          WINDANG
# 2929               None               None       WOLLONGONG
#
#      premises_state_abbreviation  premises_post_code   latitude   longitude  \
# 0                            NSW                 NaN        NaN         NaN
# 1                            NSW                 NaN        NaN         NaN
# 2                            NSW                 NaN        NaN         NaN
# 3                            NSW              2800.0        NaN         NaN
# 4                            NSW                 NaN        NaN         NaN
# ...                          ...                 ...        ...         ...
# 2925                         NSW              2528.0 -34.564200  150.858000
# 2926                         NSW              2528.0 -34.550823  150.859755
# 2927                         NSW              2575.0 -34.440900  150.424000
# 2928                         NSW              2528.0 -34.531600  150.866000
# 2929                         NSW              2500.0        NaN         NaN
#
#                                            geometry_wkt
# 0     0101000020E6100000000000000000F87F000000000000...
# 1     0101000020E6100000000000000000F87F000000000000...
# 2     0101000020E6100000000000000000F87F000000000000...
# 3     0101000020E6100000000000000000F87F000000000000...
# 4     0101000020E6100000000000000000F87F000000000000...
# ...                                                 ...
# 2925  0101000020E6100000FA7E6ABC74DB62409C33A2B43748...
# 2926  0101000020E6100000BD32141C83DB624011F28B5C8146...
# 2927  0101000020E610000021B0726891CD6240386744696F38...
# 2928  0101000020E6100000C1CAA145B6DB6240DC4603780B44...
# 2929  0101000020E6100000000000000000F87F000000000000...
#
# [2930 rows x 17 columns]

# %%
def create_wkt_element(geom, srid):
    if geom.geom_type == 'Polygon':
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)
catchments_future = gpd.read_file("catchments/catchments_future.shp")
catchments_future['geometry_wkt'] = catchments_future['geometry'].apply(lambda x: create_wkt_element(geom=x, srid=srid)) 
catchments_future = catchments_future.drop(columns="geometry")
catchments_future
# Out:
#    USE_ID    CATCH_TYPE                USE_DESC  ADD_DATE  KINDERGART  YEAR1  \
# 0    8416     HIGH_COED          Ku-ring-gai HS  20230114           0      0
# 1    8161     HIGH_BOYS            Randwick BHS  20200220           0      0
# 2    8539     HIGH_COED     SSC Blackwattle Bay  20220609           0      0
# 3    8400     HIGH_COED              St Ives HS  20230114           0      0
# 4    8555     HIGH_COED             Rose Bay SC  20200220           0      0
# 5    8556  CENTRAL_HIGH      Alexandria Park CS  20200220           0      0
# 6    8913     HIGH_COED         Inner Sydney HS  20200220           0      0
# 7    8286     HIGH_COED             Mt Annan HS  20220301           0      0
# 8    8584     HIGH_COED  Elizabeth Macarthur HS  20220301           0      0
# 9    8290     HIGH_COED       John Edmondson HS  20190520           0      0
# 10   8916     HIGH_COED            Oran Park HS  20190520           0      0
# 11   8575     HIGH_COED       Robert Townson HS  20190520           0      0
# 12   8569     HIGH_COED           Eagle Vale HS  20190520           0      0
# 13   8435     HIGH_COED           Turramurra HS  20230114           0      0
# 14   8220    HIGH_GIRLS            Randwick GHS  20200220           0      0
# 15   8922     HIGH_COED        Jerrabomberra HS  20220615           0      0
# 16   8524     HIGH_COED              Karabar HS  20220615           0      0
# 17   8919     HIGH_COED           Bungendore HS  20220615           0      0
# 18   2899       PRIMARY       Port Macquarie PS  20230208        2024   2024
# 19   4411       PRIMARY             Westport PS  20230208        2024   2024
# 20   8116     HIGH_COED             Goulburn HS  20220615           0      0
# 21   4400       PRIMARY         St Ives Park PS  20230112        2024   2024
# 22   8216     HIGH_COED           Queanbeyan HS  20220305           0      0
# 23   4331       PRIMARY              St Ives PS  20230112        2024   2024
# 24   4524       PRIMARY             Hastings PS  20230208        2024   2024
# 25   8554     HIGH_COED            HSC Westport  20230208           0      0
# 26   8364     HIGH_COED      HSC Port Macquarie  20230208           0      0
# 27   8395     HIGH_COED          Pendle Hill HS  20230112           0      0
# 28   8892     HIGH_COED       Arthur Phillip HS  20230112           0      0
# 29   8135     HIGH_COED           Parramatta HS  20230112           0      0
#
#     YEAR2  YEAR3  YEAR4  YEAR5  YEAR6  YEAR7  YEAR8  YEAR9  YEAR10  YEAR11  \
# 0       0      0      0      0      0   2024   2024   2024    2024    2024
# 1       0      0      0      0      0   2024   2024   2024    2024    2024
# 2       0      0      0      0      0      0      0      0       0    2024
# 3       0      0      0      0      0   2024   2024   2024    2024    2024
# 4       0      0      0      0      0   2024   2024   2024    2024    2024
# 5       0      0      0      0      0   2024   2024   2024    2024    2024
# 6       0      0      0      0      0   2024   2024   2024    2024    2024
# 7       0      0      0      0      0   2024   2024   2024    2024    2024
# 8       0      0      0      0      0   2024   2024   2024    2024    2024
# 9       0      0      0      0      0   2024   2024   2024    2024    2024
# 10      0      0      0      0      0   2024   2024   2024    2024    2024
# 11      0      0      0      0      0   2024   2024   2024    2024    2024
# 12      0      0      0      0      0   2024   2024   2024    2024    2024
# 13      0      0      0      0      0   2024   2024   2024    2024    2024
# 14      0      0      0      0      0   2024   2024   2024    2024    2024
# 15      0      0      0      0      0   2024   2024   2024    2025    2026
# 16      0      0      0      0      0   2024   2024   2024    2024    2024
# 17      0      0      0      0      0   2024   2024   2024    2025    2026
# 18   2024   2024   2024   2024   2024      0      0      0       0       0
# 19   2024   2024   2024   2024   2024      0      0      0       0       0
# 20      0      0      0      0      0   2024   2024   2024    2024    2024
# 21   2024   2024   2024   2024   2024      0      0      0       0       0
# 22      0      0      0      0      0   2024   2024   2024    2024    2024
# 23   2024   2024   2024   2024   2024      0      0      0       0       0
# 24   2024   2024   2024   2024   2024      0      0      0       0       0
# 25      0      0      0      0      0   2024   2024   2024    2024    2024
# 26      0      0      0      0      0   2024   2024   2024    2024    2024
# 27      0      0      0      0      0   2024   2024   2024    2024    2024
# 28      0      0      0      0      0   2024   2024   2024    2024    2024
# 29      0      0      0      0      0   2024   2024   2024    2024    2024
#
#     YEAR12                                       geometry_wkt
# 0     2024  MULTIPOLYGON (((151.19848917708944 -33.5398987...
# 1     2024  MULTIPOLYGON (((151.27151530428182 -33.9140183...
# 2     2024  MULTIPOLYGON (((151.15292370935092 -33.8393921...
# 3     2024  MULTIPOLYGON (((151.17793729938725 -33.6982001...
# 4     2024  MULTIPOLYGON (((151.28072275958445 -33.8328728...
# 5     2024  MULTIPOLYGON (((151.1949653506184 -33.88876468...
# 6     2025  MULTIPOLYGON (((151.2098245099502 -33.85422949...
# 7     2024  MULTIPOLYGON (((150.77298245154256 -34.0251624...
# 8     2024  MULTIPOLYGON (((150.7323512413543 -34.01465804...
# 9     2024  MULTIPOLYGON (((150.70497435250746 -33.9042617...
# 10    2024  MULTIPOLYGON (((150.75452293778994 -33.9547194...
# 11    2024  MULTIPOLYGON (((150.8211559179674 -33.97644041...
# 12    2024  MULTIPOLYGON (((150.8028961498485 -34.01178014...
# 13    2024  MULTIPOLYGON (((151.080732460957 -33.699885831...
# 14    2024  MULTIPOLYGON (((151.27151530428182 -33.9140183...
# 15    2027  MULTIPOLYGON (((149.20599879911867 -35.3710405...
# 16    2024  MULTIPOLYGON (((149.23537649462955 -35.3638966...
# 17    2027  MULTIPOLYGON (((149.2408471104619 -34.91439387...
# 18       0  MULTIPOLYGON (((152.9325488294347 -31.36950160...
# 19       0  MULTIPOLYGON (((152.89098463162034 -31.4492802...
# 20    2024  MULTIPOLYGON (((149.4356572439643 -34.64359280...
# 21       0  MULTIPOLYGON (((151.1745647596905 -33.70892973...
# 22    2024  MULTIPOLYGON (((149.2567431950555 -35.33185877...
# 23       0  MULTIPOLYGON (((151.16884173207154 -33.7276076...
# 24       0  MULTIPOLYGON (((152.93290106588555 -31.4488814...
# 25    2024  MULTIPOLYGON (((152.3768206204895 -30.98231105...
# 26    2024  MULTIPOLYGON (((152.92687910271997 -31.4405050...
# 27    2024  MULTIPOLYGON (((150.96083230623992 -33.7793953...
# 28    2024  MULTIPOLYGON (((151.0196486925351 -33.80865925...
# 29    2024  MULTIPOLYGON (((150.99377307298542 -33.8148954...

# %%
catchments_primary = gpd.read_file("catchments/catchments_primary.shp")
catchments_primary['geometry_wkt'] = catchments_primary['geometry'].apply(lambda x: create_wkt_element(geom=x, srid=srid)) 
catchments_primary = catchments_primary.drop(columns="geometry")
catchments_primary
# Out:
#      USE_ID CATCH_TYPE         USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2  \
# 0      2838    PRIMARY       Parklea PS  20181210          Y     Y     Y
# 1      2404    PRIMARY    Lindfield EPS  20211219          Y     Y     Y
# 2      4393    PRIMARY  Carlingford WPS  20220223          Y     Y     Y
# 3      4615    PRIMARY   Caddies Ck  PS  20181210          Y     Y     Y
# 4      3918    PRIMARY       Killara PS  20211219          Y     Y     Y
# ...     ...        ...              ...       ...        ...   ...   ...
# 1657   4383    PRIMARY   E A Southee PS  20200315          Y     Y     Y
# 1658   3275    PRIMARY    Tumbarumba PS  20200507          Y     Y     Y
# 1659   2239    PRIMARY       Jindera PS  20200507          Y     Y     Y
# 1660   3594    PRIMARY         Louth PS  20200604          Y     Y     Y
# 1661   2155    PRIMARY     Hermidale PS  20200604          Y     Y     Y
#
#      YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0        Y     Y     Y     Y     N     N     N      N      N      N     None
# 1        Y     Y     Y     Y     N     N     N      N      N      N     None
# 2        Y     Y     Y     Y     N     N     N      N      N      N     None
# 3        Y     Y     Y     Y     N     N     N      N      N      N     None
# 4        Y     Y     Y     Y     N     N     N      N      N      N     None
# ...    ...   ...   ...   ...   ...   ...   ...    ...    ...    ...      ...
# 1657     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1658     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1659     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1660     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1661     Y     Y     Y     Y     N     N     N      N      N      N     None
#
#                                            geometry_wkt
# 0     MULTIPOLYGON (((150.93563850416004 -33.7161211...
# 1     MULTIPOLYGON (((151.1833640465581 -33.74748398...
# 2     MULTIPOLYGON (((151.0451821055135 -33.77303212...
# 3     MULTIPOLYGON (((150.92567327976582 -33.7296030...
# 4     MULTIPOLYGON (((151.1537883781186 -33.75586174...
# ...                                                 ...
# 1657  MULTIPOLYGON (((147.9462089946497 -34.55863148...
# 1658  MULTIPOLYGON (((148.12885348977485 -35.6008184...
# 1659  MULTIPOLYGON (((146.86147943204122 -35.8751106...
# 1660  MULTIPOLYGON (((145.18402754685187 -29.6580498...
# 1661  MULTIPOLYGON (((146.46001243912713 -31.3168795...
#
# [1662 rows x 19 columns]

# %%
catchments_secondary = gpd.read_file("catchments/catchments_secondary.shp")
catchments_secondary['geometry_wkt'] = catchments_secondary['geometry'].apply(lambda x: create_wkt_element(geom=x, srid=srid)) 
catchments_secondary = catchments_secondary.drop(columns="geometry")
catchments_secondary
# Out:
#     USE_ID    CATCH_TYPE         USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2  \
# 0     8503     HIGH_COED     Billabong HS  20200507          N     N     N
# 1     8266     HIGH_COED  James Fallon HS  20200507          N     N     N
# 2     8505     HIGH_COED        Murray HS  20200507          N     N     N
# 3     8458     HIGH_COED     Kingswood HS  20201016          N     N     N
# 4     8559     HIGH_COED       Jamison HS  20201016          N     N     N
# ..     ...           ...              ...       ...        ...   ...   ...
# 431   8213     HIGH_BOYS      Birrong BHS  20211221          N     N     N
# 432   8108     HIGH_COED      Cessnock HS  20230405          N     N     N
# 433   3235  CENTRAL_HIGH     Tooleybuc CS  20200512          N     N     N
# 434   1115  CENTRAL_HIGH     Balranald CS  20200512          N     N     N
# 435   2213  CENTRAL_HIGH       Ivanhoe CS  20200512          N     N     N
#
#     YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0       N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 1       N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 2       N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 3       N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 4       N     N     N     N     Y     Y     Y      Y      Y      Y     None
# ..    ...   ...   ...   ...   ...   ...   ...    ...    ...    ...      ...
# 431     N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 432     N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 433     N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 434     N     N     N     N     Y     Y     Y      Y      Y      Y     None
# 435     N     N     N     N     Y     Y     Y      Y      Y      Y     None
#
#                                           geometry_wkt
# 0    MULTIPOLYGON (((146.67182402032344 -35.3144375...
# 1    MULTIPOLYGON (((147.08733806259178 -35.8627146...
# 2    MULTIPOLYGON (((146.81447829547324 -35.7834062...
# 3    MULTIPOLYGON (((150.68599834118749 -33.7403060...
# 4    MULTIPOLYGON (((150.69513440644116 -33.7562688...
# ..                                                 ...
# 431  MULTIPOLYGON (((151.05363508494244 -33.8507612...
# 432  MULTIPOLYGON (((151.4285214252146 -32.74415247...
# 433  MULTIPOLYGON (((143.37723402388323 -34.8017260...
# 434  MULTIPOLYGON (((143.65540852703225 -33.5570248...
# 435  MULTIPOLYGON (((144.3157943651705 -32.17238775...
#
# [436 rows x 19 columns]

# %%
conn.execute("""

DROP TABLE IF EXISTS catchments_future;
CREATE TABLE catchments_future (
    "USE_ID" VARCHAR(255),
    "CATCH_TYPE" VARCHAR(255),
    "USE_DESC" VARCHAR(255),
    "ADD_DATE" DATE,
    "KINDERGART" INTEGER,
    "YEAR1" INTEGER,
    "YEAR2" INTEGER,
    "YEAR3" INTEGER,
    "YEAR4" INTEGER,
    "YEAR5" INTEGER,
    "YEAR6" INTEGER,
    "YEAR7" INTEGER,
    "YEAR8" INTEGER,
    "YEAR9" INTEGER,
    "YEAR10" INTEGER,
    "YEAR11" INTEGER,
    "YEAR12" INTEGER,
    geom GEOMETRY(MULTIPOLYGON,4326)
);
""")

conn.execute("""
DROP TABLE IF EXISTS catchments_primary;
CREATE TABLE catchments_primary (
    "USE_ID" VARCHAR(255),
    "CATCH_TYPE" VARCHAR(255),
    "USE_DESC" VARCHAR(255),
    "ADD_DATE" VARCHAR(255),
    "KINDERGART" VARCHAR(255),
    "YEAR1" VARCHAR(255),
    "YEAR2" VARCHAR(255),
    "YEAR3" VARCHAR(255),
    "YEAR4" VARCHAR(255),
    "YEAR5" VARCHAR(255),
    "YEAR6" VARCHAR(255),
    "YEAR7" VARCHAR(255),
    "YEAR8" VARCHAR(255),
    "YEAR9" VARCHAR(255),
    "YEAR10" VARCHAR(255),
    "YEAR11" VARCHAR(255),
    "YEAR12" VARCHAR(255),
    "PRIORITY" VARCHAR(255),
    geom GEOMETRY(MULTIPOLYGON,4326)
);
""")

conn.execute("""
DROP TABLE IF EXISTS catchments_secondary;
CREATE TABLE catchments_secondary (
    "USE_ID" VARCHAR(255),
    "CATCH_TYPE" VARCHAR(255),
    "USE_DESC" VARCHAR(255),
    "ADD_DATE" VARCHAR(255),
    "KINDERGART" VARCHAR(255),
    "YEAR1" VARCHAR(255),
    "YEAR2" VARCHAR(255),
    "YEAR3" VARCHAR(255),
    "YEAR4" VARCHAR(255),
    "YEAR5" VARCHAR(255),
    "YEAR6" VARCHAR(255),
    "YEAR7" VARCHAR(255),
    "YEAR8" VARCHAR(255),
    "YEAR9" VARCHAR(255),
    "YEAR10" VARCHAR(255),
    "YEAR11" VARCHAR(255),
    "YEAR12" VARCHAR(255),
    "PRIORITY" VARCHAR(255),
    geom GEOMETRY(MULTIPOLYGON,4326)
);
""")

# %%
catchments_future.dtypes
# Out:
# USE_ID          object
# CATCH_TYPE      object
# USE_DESC        object
# ADD_DATE        object
# KINDERGART       int32
# YEAR1            int32
# YEAR2            int32
# YEAR3            int32
# YEAR4            int32
# YEAR5            int32
# YEAR6            int32
# YEAR7            int32
# YEAR8            int32
# YEAR9            int32
# YEAR10           int32
# YEAR11           int32
# YEAR12           int32
# geometry_wkt    object
# dtype: object

# %%
catchments_future.to_sql("catchments_future", conn, if_exists='replace', index=False, dtype={
    'geometry_wkt': Geometry('MULTIPOLYGON', srid)
})
catchments_primary.to_sql("catchments_primary", conn, if_exists='replace', index=False, dtype={
    'geometry_wkt': Geometry('MULTIPOLYGON', srid)
})
catchments_secondary.to_sql("catchments_secondary", conn, if_exists='replace', index=False, dtype={
    'geometry_wkt': Geometry('MULTIPOLYGON', srid)
})
# Out:
# 436

# %%
total_catchments = pd.concat([catchments_primary, catchments_secondary, catchments_future])
total_catchments
# Out:
#    USE_ID CATCH_TYPE            USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2  \
# 0    2838    PRIMARY          Parklea PS  20181210          Y     Y     Y
# 1    2404    PRIMARY       Lindfield EPS  20211219          Y     Y     Y
# 2    4393    PRIMARY     Carlingford WPS  20220223          Y     Y     Y
# 3    4615    PRIMARY      Caddies Ck  PS  20181210          Y     Y     Y
# 4    3918    PRIMARY          Killara PS  20211219          Y     Y     Y
# ..    ...        ...                 ...       ...        ...   ...   ...
# 25   8554  HIGH_COED        HSC Westport  20230208          0     0     0
# 26   8364  HIGH_COED  HSC Port Macquarie  20230208          0     0     0
# 27   8395  HIGH_COED      Pendle Hill HS  20230112          0     0     0
# 28   8892  HIGH_COED   Arthur Phillip HS  20230112          0     0     0
# 29   8135  HIGH_COED       Parramatta HS  20230112          0     0     0
#
#    YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0      Y     Y     Y     Y     N     N     N      N      N      N     None
# 1      Y     Y     Y     Y     N     N     N      N      N      N     None
# 2      Y     Y     Y     Y     N     N     N      N      N      N     None
# 3      Y     Y     Y     Y     N     N     N      N      N      N     None
# 4      Y     Y     Y     Y     N     N     N      N      N      N     None
# ..   ...   ...   ...   ...   ...   ...   ...    ...    ...    ...      ...
# 25     0     0     0     0  2024  2024  2024   2024   2024   2024      NaN
# 26     0     0     0     0  2024  2024  2024   2024   2024   2024      NaN
# 27     0     0     0     0  2024  2024  2024   2024   2024   2024      NaN
# 28     0     0     0     0  2024  2024  2024   2024   2024   2024      NaN
# 29     0     0     0     0  2024  2024  2024   2024   2024   2024      NaN
#
#                                          geometry_wkt
# 0   MULTIPOLYGON (((150.93563850416004 -33.7161211...
# 1   MULTIPOLYGON (((151.1833640465581 -33.74748398...
# 2   MULTIPOLYGON (((151.0451821055135 -33.77303212...
# 3   MULTIPOLYGON (((150.92567327976582 -33.7296030...
# 4   MULTIPOLYGON (((151.1537883781186 -33.75586174...
# ..                                                ...
# 25  MULTIPOLYGON (((152.3768206204895 -30.98231105...
# 26  MULTIPOLYGON (((152.92687910271997 -31.4405050...
# 27  MULTIPOLYGON (((150.96083230623992 -33.7793953...
# 28  MULTIPOLYGON (((151.0196486925351 -33.80865925...
# 29  MULTIPOLYGON (((150.99377307298542 -33.8148954...
#
# [2128 rows x 19 columns]

# %%
total_catchments.dtypes
# Out:
# USE_ID          object
# CATCH_TYPE      object
# USE_DESC        object
# ADD_DATE        object
# KINDERGART      object
# YEAR1           object
# YEAR2           object
# YEAR3           object
# YEAR4           object
# YEAR5           object
# YEAR6           object
# YEAR7           object
# YEAR8           object
# YEAR9           object
# YEAR10          object
# YEAR11          object
# YEAR12          object
# PRIORITY        object
# geometry_wkt    object
# dtype: object

# %%
total_catchments.to_sql("total_catchments", conn, if_exists='replace', index=False, dtype={
    'geometry_wkt': Geometry('MULTIPOLYGON', srid)
})
# Out:
# 128
